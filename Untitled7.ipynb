# %% [markdown]
# <a href="https://colab.research.google.com/github/salonisinha40/Sales_Analysis/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/8. Netflix Dataset.csv')

# %%
#head
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#tail
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
#no of rows and cols
df.shape
# Out:
# (7789, 11)

# %%
#show total no of elements in dataset
df.size
# Out:
# 85679

# %%
#to show all columns name
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#to show data types of each columns
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#to show index,columns,null count,data type, and memory used
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#is there any duplicate records ? If yes then remove
df[df.duplicated()]
df.drop_duplicates(inplace=True)

# %%
#to find nulls
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#For house of cards, what is show id and who is director?
filt=(df['Title']=='House of Cards')
df.loc[filt,['Show_Id','Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
# In which year highest no of Tv shows and movies were release?
df['Date_new']=pd.to_datetime(df['Release_Date'])
df['Year']=df['Date_new'].dt.year
df['Year'].value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %%
#plot the above result in barchart
df['Date_new']=pd.to_datetime(df['Release_Date'])
df['Year']=df['Date_new'].dt.year
df['Year'].value_counts()
plt.bar(df['Year'].value_counts().index,df['Year'].value_counts().values)
# Out:
# <BarContainer object of 14 artists>

# %%
#How many movies and Tv shows are in this dataset?
df['Category'].value_counts()
sns.barplot(x=df['Category'].value_counts().index,y=df['Category'].value_counts().values)
# Out:
# <Axes: >

# %%
# Show all the movies that were released in year 2020?
filt=(df['Category']=='Movie') & (df['Year']==2020)
df.loc[filt,['Title','Year']]
# Out:
#                                         Title    Year
# 4                                          21  2020.0
# 6                                         122  2020.0
# 14                                       3022  2020.0
# 27                                     #Alive  2020.0
# 28              #AnneFrank - Parallel Stories  2020.0
# ...                                       ...     ...
# 7762                                Zaki Chan  2020.0
# 7783                                     Zoom  2020.0
# 7784                                     Zozo  2020.0
# 7786                        Zulu Man in Japan  2020.0
# 7788  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  2020.0
#
# [1312 rows x 2 columns]

# %%
#show titles of all TV shows that were released in India only
df
filt=(df['Country']=='India') & (df['Category']=='TV Show')
df.loc[filt,'Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
#show top 10 directors who gave highest no of TV shows and movies o netflix
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
#show all records where category is movie and type is comedies or country is UK
df.head()
filt=((df['Category']=='Movie') & (df['Type'].str.contains('Comedies'))) | (df['Country']=='UK')
df[filt]
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# 37       s38    Movie                         #Selfie 69      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %%
#In how many movies/shows Tom Cruise was cast?
df.head()
filt=(df['Cast'].notnull()) & (df['Cast'].str.contains('Tom Cruise'))
# If we don't use df['Cast'].notnull() then, we will get error as we have null values in cast and str.contains expects non null values. 
df[filt]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description   Date_new    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
#what are the different ratings defined by Netflix?
df.head()
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#How many movies got TV-14 rating in canada?
df.head()
filt=(df['Rating']=='TV-14') & (df['Category']=='Movie') & (df['Country']=='Canada')
df[filt].shape
# Out:
# (11, 13)

# %%
#How many TV show got R rating after 2018?
df.head()
filt=(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year']>2018)
df[filt].shape
# Out:
# (1, 13)

# %%
# what is the maximum duration of a TV show and movie in netflix?
k=df.groupby('Category')
k.get_group('TV Show')
#df[['Duration', 'Unit']] = df['Duration'].str.split(' ', expand=True)
k['Duration'].max()
# Out:
# Category
# Movie      99
# TV Show     9
# Name: Duration, dtype: object

# %%
#which individual country has highest no of tv shows?
df.head()
filt=df['Category']=='TV Show'
df1=df[filt]
df1['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %%
#sort database by year
df.sort_values(by='Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...
